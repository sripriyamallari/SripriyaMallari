# %% [markdown]
# <a href="https://colab.research.google.com/github/sripriyamallari/SripriyaMallari/blob/main/Language_Translation_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gradio requests

# %%
import gradio as gr
import requests

# Supported languages
languages = {
    "Auto Detect": "auto",
    "English": "en",
    "Telugu": "te",
    "Hindi": "hi",
    "Tamil": "ta",
    "Kannada": "kn",
    "Malayalam": "ml",
    "Marathi": "mr",
    "Bengali": "bn",
    "Gujarati": "gu",
    "Punjabi": "pa",
    "French": "fr",
    "German": "de",
    "Spanish": "es",
    "Italian": "it",
    "Portuguese": "pt",
    "Russian": "ru",
    "Arabic": "ar",
    "Chinese": "zh",
    "Japanese": "ja",
    "Korean": "ko"
}

language_names = list(languages.keys())


def translate_text(text, source_language, target_language):

    if not text.strip():
        return "Please enter some text."

    source = languages[source_language]
    target = languages[target_language]

    if target == "auto":
        return "Please select a target language."

    # If source and target are same
    if source == target:
        return text

    # MyMemory Translation API
    url = "https://api.mymemory.translated.net/get"

    params = {
        "q": text,
        "langpair": f"{source}|{target}"
    }

    try:
        response = requests.get(
            url,
            params=params,
            timeout=15
        )

        data = response.json()

        translated = data["responseData"]["translatedText"]

        return translated

    except Exception as e:
        return "Translation failed. Please try again."


# Create the website
with gr.Blocks(title="Language Translation Tool") as demo:

    gr.Markdown(
        """
        # 🌐 Language Translation Tool

        ### Translate text between different languages
        """
    )

    with gr.Row():

        source = gr.Dropdown(
            choices=language_names,
            value="Auto Detect",
            label="Source Language"
        )

        target = gr.Dropdown(
            choices=language_names,
            value="Telugu",
            label="Target Language"
        )

    input_text = gr.Textbox(
        label="Enter Text",
        placeholder="Type your text here...",
        lines=6
    )

    translate_button = gr.Button(
        "🔄 Translate",
        variant="primary"
    )

    output_text = gr.Textbox(
        label="Translated Text",
        lines=6
    )

    translate_button.click(
        fn=translate_text,
        inputs=[input_text, source, target],
        outputs=output_text
    )

    gr.Markdown(
        """
        ### Optional Features
        You can copy the translated text or use your browser's
        text-to-speech feature.
        """
    )


demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://044ddd17e350246d35.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://044ddd17e350246d35.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
